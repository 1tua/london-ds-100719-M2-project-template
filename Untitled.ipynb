# %%
import sqlite3

# %%
conn = sqlite3.connect('database.sqlite')
cur = conn.cursor()

# %%
cur.execute("""SELECT *
                FROM matches
                LIMIT 10""")

# %%
cur.fetchall()
# Out:
# [(1, 'D2', 2009, '2010-04-04', 'Oberhausen', 'Kaiserslautern', 2, 1, 'H'),
#  (2, 'D2', 2009, '2009-11-01', 'Munich 1860', 'Kaiserslautern', 0, 1, 'A'),
#  (3, 'D2', 2009, '2009-10-04', 'Frankfurt FSV', 'Kaiserslautern', 1, 1, 'D'),
#  (4, 'D2', 2009, '2010-02-21', 'Frankfurt FSV', 'Karlsruhe', 2, 1, 'H'),
#  (5, 'D2', 2009, '2009-12-06', 'Ahlen', 'Karlsruhe', 1, 3, 'A'),
#  (6, 'D2', 2009, '2010-04-03', 'Union Berlin', 'Karlsruhe', 1, 1, 'D'),
#  (7, 'D2', 2009, '2009-08-14', 'Paderborn', 'Karlsruhe', 2, 0, 'H'),
#  (8, 'D2', 2009, '2010-03-08', 'Bielefeld', 'Karlsruhe', 0, 1, 'A'),
#  (9, 'D2', 2009, '2009-09-26', 'Kaiserslautern', 'Karlsruhe', 2, 0, 'H'),
#  (10, 'D2', 2009, '2009-11-21', 'Hansa Rostock', 'Karlsruhe', 2, 1, 'H')]

# %%
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
import pandas as pd

# %%
cur.execute("""SELECT * FROM matches LIMIT 10;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.head()
# Out:
#    Match_ID Div  Season        Date       HomeTeam        AwayTeam  FTHG  \
# 0         1  D2    2009  2010-04-04     Oberhausen  Kaiserslautern     2
# 1         2  D2    2009  2009-11-01    Munich 1860  Kaiserslautern     0
# 2         3  D2    2009  2009-10-04  Frankfurt FSV  Kaiserslautern     1
# 3         4  D2    2009  2010-02-21  Frankfurt FSV       Karlsruhe     2
# 4         5  D2    2009  2009-12-06          Ahlen       Karlsruhe     1
#
#    FTAG FTR
# 0     1   H
# 1     1   A
# 2     1   D
# 3     1   H
# 4     3   A

# %%
cur.execute("""SELECT * FROM teams WHERE Season== 2011 ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.TeamName.nunique()
# Out:
# 36

# %%
cur.execute("""SELECT * FROM unique_teams ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#           TeamName  Unique_Team_ID
# 0    Bayern Munich               1
# 1         Dortmund               2
# 2       Leverkusen               3
# 3       RB Leipzig               4
# 4       Schalke 04               5
# ..             ...             ...
# 123        Burnley             124
# 124      Blackpool             125
# 125        Swansea             126
# 126        Cardiff             127
# 127    Bournemouth             128
#
# [128 rows x 2 columns]

# %%
cur.execute("""SELECT * FROM Teams_in_Matches ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.hea
# Out:
#    Match_ID  Unique_Team_ID
# 0         1              26
# 1         1              46
# 2         2              26
# 3         2              42
# 4         3              26
# 5         3              44
# 6         4              29
# 7         4              44
# 8         5              29
# 9         5              49

# %%
cur.execute("""SELECT * FROM FlatView ;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.head(10)
# Out:
#    Match_ID Div  Season        Date        HomeTeam        AwayTeam  FTHG  \
# 0         1  D2    2009  2010-04-04      Oberhausen  Kaiserslautern     2
# 1         2  D2    2009  2009-11-01     Munich 1860  Kaiserslautern     0
# 2         3  D2    2009  2009-10-04   Frankfurt FSV  Kaiserslautern     1
# 3         4  D2    2009  2010-02-21   Frankfurt FSV       Karlsruhe     2
# 4         5  D2    2009  2009-12-06           Ahlen       Karlsruhe     1
# 5         6  D2    2009  2010-04-03    Union Berlin       Karlsruhe     1
# 6         7  D2    2009  2009-08-14       Paderborn       Karlsruhe     2
# 7         8  D2    2009  2010-03-08       Bielefeld       Karlsruhe     0
# 8         9  D2    2009  2009-09-26  Kaiserslautern       Karlsruhe     2
# 9        10  D2    2009  2009-11-21   Hansa Rostock       Karlsruhe     2
#
#    FTAG FTR AvgAgeHome  ... ForeignPlayersHome ForeignplayersAways KaderHome  \
# 0     1   H         25  ...                  8                  13        29
# 1     1   A         24  ...                 18                  13        33
# 2     1   D         26  ...                 20                  13        34
# 3     1   H         26  ...                 20                   9        34
# 4     3   A         25  ...                 14                   9        37
# 5     1   D         25  ...                  8                   9        29
# 6     0   H         25  ...                  6                   9        31
# 7     1   A         25  ...                 15                   9        31
# 8     0   H         23  ...                 13                   9        32
# 9     1   H         25  ...                  8                   9        31
#
#   KaderAway StadiumCapacity StadiumCapacityAway AvgMarketValueHome  \
# 0        32           47728               47728             305000
# 1        32           47728               47728             658000
# 2        32           47728               47728             385000
# 3        37           47728               47728             385000
# 4        37           47728               47728             349000
# 5        37           47728               47728             327000
# 6        37           47728               47728             309000
# 7        37           47728               47728             883000
# 8        37           47728               47728             747000
# 9        37           47728               47728             665000
#
#   MarketValueAway OverallMarketValueHome OverallMarketValueAway
# 0          747000                8850000               23900000
# 1          747000               21700000               23900000
# 2          747000               13100000               23900000
# 3          570000               13100000               21100000
# 4          570000               12930000               21100000
# 5          570000                9480000               21100000
# 6          570000                9580000               21100000
# 7          570000               27380000               21100000
# 8          570000               23900000               21100000
# 9          570000               20630000               21100000
#
# [10 rows x 21 columns]

# %%
cur.execute("""SELECT * FROM matches LIMIT 10;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df.head()
# Out:
#    Match_ID Div  Season        Date       HomeTeam        AwayTeam  FTHG  \
# 0         1  D2    2009  2010-04-04     Oberhausen  Kaiserslautern     2
# 1         2  D2    2009  2009-11-01    Munich 1860  Kaiserslautern     0
# 2         3  D2    2009  2009-10-04  Frankfurt FSV  Kaiserslautern     1
# 3         4  D2    2009  2010-02-21  Frankfurt FSV       Karlsruhe     2
# 4         5  D2    2009  2009-12-06          Ahlen       Karlsruhe     1
#
#    FTAG FTR
# 0     1   H
# 1     1   A
# 2     1   D
# 3     1   H
# 4     3   A

# %%
cur.execute("""SELECT HomeTeam as Team, sum(FTHG) as homegoals, Season 
               FROM matches 
               WHERE Season == 2011
               GROUP BY 1;
               """)
dfh = pd.DataFrame(cur.fetchall())
dfh.columns = [x[0] for x in cur.description]
dfh.head()
# Out:
#             Team  homegoals  Season
# 0         Aachen         15    2011
# 1        Arsenal         39    2011
# 2    Aston Villa         20    2011
# 3       Augsburg         20    2011
# 4  Bayern Munich         49    2011

# %%
cur.execute("""SELECT AwayTeam as Team, sum(FTAG) as awaygoals, Season 
               FROM matches 
               WHERE Season == 2011
               GROUP BY 1;
               """)
dfa = pd.DataFrame(cur.fetchall())
dfa.columns = [x[0] for x in cur.description]
dfa.head()
# Out:
#             Team  awaygoals  Season
# 0         Aachen         15    2011
# 1        Arsenal         35    2011
# 2    Aston Villa         17    2011
# 3       Augsburg         16    2011
# 4  Bayern Munich         28    2011

# %%
combine = pd.merge(dfh, dfa, how='inner', on=['Team'])
combine.head()
# Out:
#             Team  homegoals  Season_x  awaygoals  Season_y
# 0         Aachen         15      2011         15      2011
# 1        Arsenal         39      2011         35      2011
# 2    Aston Villa         20      2011         17      2011
# 3       Augsburg         20      2011         16      2011
# 4  Bayern Munich         49      2011         28      2011

# %%
combine['total_goals'] = combine.apply(lambda x: x['homegoals'] + x['awaygoals'], axis=1)
combine.head()
# Out:
#             Team  homegoals  Season_x  awaygoals  Season_y  total_goals
# 0         Aachen         15      2011         15      2011           30
# 1        Arsenal         39      2011         35      2011           74
# 2    Aston Villa         20      2011         17      2011           37
# 3       Augsburg         20      2011         16      2011           36
# 4  Bayern Munich         49      2011         28      2011           77

# %%
mdf.head()
mdf.FTR.unique()
# Out:
# array(['A', 'H', 'D'], dtype=object)

# %%
cur.execute("""SELECT * FROM matches WHERE Season == 2011;""")
mdf = pd.DataFrame(cur.fetchall())
mdf.columns = [x[0] for x in cur.description]
mdf.head()
# Out:
#    Match_ID Div  Season        Date   HomeTeam       AwayTeam  FTHG  FTAG FTR
# 0      1092  D1    2011  2012-03-31   Nurnberg  Bayern Munich     0     1   A
# 1      1093  D1    2011  2011-12-11  Stuttgart  Bayern Munich     1     2   A
# 2      1094  D1    2011  2011-08-13  Wolfsburg  Bayern Munich     0     1   A
# 3      1095  D1    2011  2011-11-27      Mainz  Bayern Munich     3     2   H
# 4      1096  D1    2011  2012-02-18   Freiburg  Bayern Munich     0     0   D

# %%
wins=[]
for x in range(0,len(mdf)):
    if mdf.FTR[x]== 'H':
        wins.append(mdf.HomeTeam[x])
    elif mdf.FTR[x]=='A':
        wins.append(mdf.AwayTeam[x])

# %%
num_of_wins=[]
for x in combine['Team']:
    num_of_wins.append(wins.count(x))

# %%
combine['num_of_wins']=num_of_wins

# %%
combine.head()
# Out:
#             Team  homegoals  Season_x  awaygoals  Season_y  total_goals  \
# 0         Aachen         15      2011         15      2011           30
# 1        Arsenal         39      2011         35      2011           74
# 2    Aston Villa         20      2011         17      2011           37
# 3       Augsburg         20      2011         16      2011           36
# 4  Bayern Munich         49      2011         28      2011           77
#
#    num_of_wins
# 0            6
# 1           21
# 2            7
# 3            8
# 4           23

# %%
lost=[]
for x in range(0,len(mdf)):
    if mdf.FTR[x]== 'A':
        lost.append(mdf.HomeTeam[x])
    elif mdf.FTR[x]=='H':
        lost.append(mdf.AwayTeam[x])

# %%
num_of_lost=[]
for x in combine['Team']:
    num_of_lost.append(lost.count(x))

# %%
combine['num_of_lost']=num_of_lost

# %%
combine.head()
# Out:
#             Team  homegoals  Season_x  awaygoals  Season_y  total_goals  \
# 0         Aachen         15      2011         15      2011           30
# 1        Arsenal         39      2011         35      2011           74
# 2    Aston Villa         20      2011         17      2011           37
# 3       Augsburg         20      2011         16      2011           36
# 4  Bayern Munich         49      2011         28      2011           77
#
#    num_of_wins  num_of_lost
# 0            6           15
# 1           21           10
# 2            7           14
# 3            8           12
# 4           23            7

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(30,20))
ax = sns.barplot(x="num_of_wins", y="Team", data=combine, color='red')
ax2=sns.barplot(x="num_of_lost", y="Team", data=combine, color='blue')
plt.xlabel('num of games')
plt.ylabel('Team')
# Out:
# Text(0, 0.5, 'Team')
